# %%
# %cd ..
# %load_ext autoreload
# %autoreload 2
# Out:
# /home/clay/userdata/title_generation

# %%
from pathlib import Path
from pyabc import pyabc

from data_utils import prepare_abc

import shutil

# %%
session_dir = Path('abc_dataset/folk_rnn_abc_key_cleaned')
session_abcs = list(session_dir.rglob('*.abc'))
session_abcs.sort(key=lambda x: int(x.stem))

# %%
session_abcs
# Out:
# [PosixPath('abc_dataset/folk_rnn_abc_key_cleaned/00001.abc'),
#  PosixPath('abc_dataset/folk_rnn_abc_key_cleaned/00002.abc'),
#  PosixPath('abc_dataset/folk_rnn_abc_key_cleaned/00003.abc'),
#  PosixPath('abc_dataset/folk_rnn_abc_key_cleaned/00004.abc'),
#  PosixPath('abc_dataset/folk_rnn_abc_key_cleaned/00005.abc'),
#  PosixPath('abc_dataset/folk_rnn_abc_key_cleaned/00006.abc'),
#  PosixPath('abc_dataset/folk_rnn_abc_key_cleaned/00007.abc'),
#  PosixPath('abc_dataset/folk_rnn_abc_key_cleaned/00008.abc'),
#  PosixPath('abc_dataset/folk_rnn_abc_key_cleaned/00009.abc'),
#  PosixPath('abc_dataset/folk_rnn_abc_key_cleaned/00010.abc'),
#  PosixPath('abc_dataset/folk_rnn_abc_key_cleaned/00011.abc'),
#  PosixPath('abc_dataset/folk_rnn_abc_key_cleaned/00012.abc'),
#  PosixPath('abc_dataset/folk_rnn_abc_key_cleaned/00013.abc'),
#  PosixPath('abc_dataset/folk_rnn_abc_key_cleaned/00014.abc'),
#  PosixPath('abc_dataset/folk_rnn_abc_key_cleaned/00015.abc'),
# ...

# %%
session_tunes, error_list = prepare_abc(session_abcs)
# Out:
# Error in token measure_offset: <Beam "|">
# Error in token measure_offset: <Beam "|">
# Error in token measure_offset: <Beam "|">
# Error in meas_offset_from_repeat_start: <Beam "|">
# Error in token measure_offset: <Beam "|">
# Error in meas_offset_from_repeat_start: <Tie "-">
# Error in token measure_offset: <Beam "|">
# Error in meas_offset_from_repeat_start: <Beam ":|">
# Error in meas_offset_from_repeat_start: <Beam "|:">
# Error in meas_offset_from_repeat_start: <Beam "|:">
# Error in meas_offset_from_repeat_start: <Beam "|:">
# Error in token measure_offset: <Beam "|">

# %%
len(session_tunes), len(error_list), len(session_abcs)
# Out:
# (17601, 4, 17605)

# %%
session_tunes[0].header
# Out:
# {'reference number': '1',
#  'tune title': "'G Iomain Nan Gamhna",
#  'source': 'https://thesession.org/tunes/11931#setting11931',
#  'transcription': 'G Major',
#  'rhythm': 'slip jig',
#  'meter': '9/8',
#  'unit note length': '1/8',
#  'key': 'C Major'}

# %%
title_tunes = [tune for tune in session_tunes if 'x' != tune.header['tune title']]
title_set = set([tune.header['tune title'] for tune in title_tunes])

# %%
len(title_tunes), len(title_set)
# Out:
# (14981, 7153)

# %% [markdown]
# ## Title analysis using opneai api

# %%
# correct the title by change 'The' position to the front of the title
single_title = [title for title in title_set if len(title.split(' ')) == 1]
title_the_fixed = []
for title in title_set:
  title_split = title.split(' ')
  if title_split[-1] == 'The':
    title_the_fixed.append(' '.join(title_split[-1:] + title_split[:-1])[:-1])
  else:
    title_the_fixed.append(title)

# %%
collect_title = []
collect_tunes = []

for tune in title_tunes:
  #if tune.header['tune title'] not in collect_title:
    collect_title.append(tune.header['tune title'])
    collect_tunes.append(tune)
len(collect_tunes), len(collect_title)
# Out:
# (14981, 14981)

# %%
unique_title_list = list(set(collect_title))
unique_title_list[200:500]
# Out:
# ["I Wonder What's Keeping My True Love Tonight",
#  'Fried Black Pudding And Laverbread',
#  'Emyvale, The',
#  "Croppies' March, The",
#  'Reel De Minuit',
#  'Molly Put The Kettle On',
#  'Fare Well',
#  "Pachelbel's Frolics",
#  'Saffron And Blue',
#  "Dan Sullivan's Fancy",
#  'Reed Makers',
#  'Reluctant Traveller, The',
#  'Mrs. Hamilton Of Pencaitland',
#  'Cuckfield Place',
#  "Martin Rochford's",
#  'Bank Of Turf, The',
#  "Lord Moira's Welcome To Scotland",
#  'East Neuk O Fife, The',
#  'Gin I Were Where Gadie Rins',
#  'Ballerina, The',
#  'Independence, The',
#  'Wynding The Hay',
#  "Herr Roloff's Farewell",
#  'Amaryllis Schottische, The',
#  'Hamnataing',
#  "Dinny O'Brien's",
#  "Grant's",
#  'Drunken Sailor, The',
#  'Valse A Donald',
#  'Humours Of Westmeath, The',
#  "Hennigan's",
#  "It's Howling Outside",
#  "Mulhaire's",
#  'Swat The Fly',
#  'Harvest Ricks',
#  "Charlie Harris's",
#  'Softly Robin',
#  'Goathland Square Eight',
#  "Fred's Favourite",
# ...

# %%
unique_title_list
# Out:
# ["Coyle's Piano",
#  "Bald Bishop's, The",
#  'Miss Sarah McFadyen',
#  'Happy, The',
#  "Highlander's Return",
#  'Farewell To Randolph',
#  'Boys From Scart',
#  'Birlinn Ghoraidh Chrobhain',
#  'Fog In The Bog, The',
#  'Ton, The',
#  'Hawthornden',
#  'Miss Bruce',
#  "I'm Ready Now!",
#  'Banjo Breakdown',
#  'Whiskey The Dolphin',
#  'Rocky Road To Mount Collins, The',
#  'Square Of Crossmaglen, The',
#  'Twenty Men From Dublin',
#  "Lemmy Brazil's",
#  'Dying Rebel, The',
#  'Tappaghyn Jiargey',
#  "Willie Hunter's Compliments To Dan R. MacDonald",
#  'Joys Of Quebec',
#  'Cowboy, The',
#  'Callow Lake',
#  'Whistler, The',
#  "Mackilmoyle's",
#  'Glassel, The',
#  'Scottish Lovers, The',
#  'Shrewsbury Lasses',
#  "Conlan's Well",
#  "Character's",
#  "Caulfield's",
#  'Connie In The Pool',
#  'Shady, The',
#  'Miss Crawford',
#  'Farewell To Erin',
#  'Rambler, The',
#  "Tom Martin's",
#  'Border',
#  'Smokey Lum, The',
#  'Da Peerie Hoose Under Da Hill',
#  'Blacktown',
# ...

# %%
import os
import openai
openai.organization = "clayryu"
openai.api_key = "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"

# %%
response = openai.Completion.create(
  model="text-davinci-003",
  prompt=f"in below titles can you figure out titles which is not originated from English? \n\n{unique_title_list[:200]}",
  temperature=0.7,
  max_tokens=150,
  top_p=1.0,
  frequency_penalty=0,
  presence_penalty=0
)

# %%
import os
import sys
import urllib.request

client_id = "EFVKF10RAlJ1RCn0aXwz"
client_secret = "x4R27oJktg"
encQuery = urllib.parse.quote('Muiñeira De Cabana')
data = "query=" + encQuery
url = "https://openapi.naver.com/v1/papago/detectLangs"
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request, data=data.encode("utf-8"))
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    lang = response_body.decode('utf-8')[13:-2]
    print(lang)
# Out:
# pt

# %% [markdown]
# ## using naver API

# %%
collect_title = []
collect_tunes = []

for tune in title_tunes:
  #if tune.header['tune title'] not in collect_title:
    collect_title.append(tune.header['tune title'])
    collect_tunes.append(tune)

# %%
len(collect_title), collect_title
# Out:
# (14981,
#  ["'G Iomain Nan Gamhna",
#   'Devil In The Kitchen, The',
#   '10th Bat Crossing Rhine',
#   '10th Bat Crossing Rhine',
#   '10th Bat Crossing Rhine',
#   'Hoch Lebe Der Mann Mit Dem Hut',
#   '1st August',
#   '1st August',
#   '2D Or Not 2D',
#   '30 Year, The',
#   '30 Year, The',
#   '30th Anniversary',
#   '30th Anniversary',
#   '42 Beech Avenue',
#   '5:30am',
#   '6-8 Du Petit Sarny',
#   "72nd Highlanders' Farewell To Aberdeen, The",
#   "Tommy Peoples'",
#   "79th's Farewell To Gibraltar",
#   '93 Not Out',
#   'A Barrel Of Knives',
#   'A Bhriogais Uallach',
#   'A Birthday',
#   'A Birthday',
#   'A Birthday',
#   'A Birthday',
#   'A Birthday',
#   'Britches, The',
#   'A Bottle Of Vodka, Twenty Marlboro Reds And £50 Cashback, Please',
#   'A Bottle Of Vodka, Twenty Marlboro Reds And £50 Cashback, Please',
#   'A Breton In Paris',
#   'A Breton In Paris',
#   'Moll Roe',
#   'Love At The Window',
#   "A Chur Nan Gobhar As A 'Chreig",
#   'Molly On The Shore',
# ...

# %% [markdown]
# ## azure_language_cognition

# %%
import os
import sys
import urllib.request

avail_unq_tunes_1 = []
for tune in collect_tunes[:5000]:
    title = tune.header["tune title"]
    client_id = "EFVKF10RAlJ1RCn0aXwz"
    client_secret = "x4R27oJktg"
    encQuery = urllib.parse.quote(title)
    data = "query=" + encQuery
    url = "https://openapi.naver.com/v1/papago/detectLangs"
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request, data=data.encode("utf-8"))
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        lang = response_body.decode('utf-8')[13:-2]
        if lang == 'en':
            avail_unq_tunes_1.append(tune)
            
    else:
        print("Error Code:" + rescode)

# %%
# too many requests raise error
avail_unq_tunes_2 = []
for tune in collect_tunes[5000:10000]:
    title = tune.header["tune title"]
    client_id = "EFVKF10RAlJ1RCn0aXwz"
    client_secret = "x4R27oJktg"
    encQuery = urllib.parse.quote(title)
    data = "query=" + encQuery
    url = "https://openapi.naver.com/v1/papago/detectLangs"
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request, data=data.encode("utf-8"))
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        lang = response_body.decode('utf-8')[13:-2]
        if lang == 'en':
            avail_unq_tunes_2.append(tune)

    else:
        print("Error Code:" + rescode)

# %%
# too many requests raise error
avail_unq_tunes_3 = []
for tune in collect_tunes[10000:]:
    title = tune.header["tune title"]
    client_id = "EFVKF10RAlJ1RCn0aXwz"
    client_secret = "x4R27oJktg"
    encQuery = urllib.parse.quote(title)
    data = "query=" + encQuery
    url = "https://openapi.naver.com/v1/papago/detectLangs"
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request, data=data.encode("utf-8"))
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        lang = response_body.decode('utf-8')[13:-2]
        if lang == 'en':
            avail_unq_tunes_3.append(tune)

    else:
        print("Error Code:" + rescode)

# %%
ref_nums = []
avail_unq_tunes = avail_unq_tunes_1 + avail_unq_tunes_2 + avail_unq_tunes_3
for tune in avail_unq_tunes:
  ref_nums.append(int(tune.header['reference number']))
  
len(ref_nums)
# Out:
# 11454

# %%
for ref_num in ref_nums:
  with open(f'abc_dataset/folk_rnn_abc_key_cleaned/{str(ref_num).zfill(5)}.abc', 'r') as f:
    abc = f.read()
    abc_split = abc.split("\n")
    if abc_split[1][-3:] == 'The':
      split = abc_split[1].split(' ')
      split.insert(1, 'The')
      split.pop()
      abc_split[1] = ' '.join(split)
      abc_split[1] = abc_split[1][:-1]
      new_abc = '\n'.join(abc_split)
    else:
      new_abc = abc
# Out:
# X: 2
# T: The Devil In The Kitchen
# S: https://thesession.org/tunes/1746#setting1746
# Z: A Mixolydian
# R: strathspey
# M: 4/4
# L: 1/8
# K: C Mixolydian
# ...

# %%
for ref_num in ref_nums:
  with open(f'abc_dataset/folk_rnn_abc_key_cleaned/{str(ref_num).zfill(5)}.abc', 'r') as f:
    abc = f.read()

    # Perform modifications on the contents of 'abc'
    abc_split = abc.split("\n")
    if abc_split[1][-3:] == 'The':
      split = abc_split[1].split(' ')
      split.insert(1, 'The')
      split.pop()
      abc_split[1] = ' '.join(split)
      abc_split[1] = abc_split[1][:-1]
      new_abc = '\n'.join(abc_split)
    else:
      new_abc = abc
    
    # Save the modified contents to another file in the desired directory
    with open(f'abc_dataset/folk_rnn_abc_key_cleaned_for_title/{str(ref_num).zfill(5)}.abc', 'w') as f:
      f.write(new_abc)

# %%
with open('abc_dataset/folk_rnn_abc_key_cleaned/avail_unq_title_data.txt', 'w') as f:
  for ref_num in ref_nums:
    f.write('abc_dataset/folk_rnn_abc_key_cleaned/%d.abc')

# %%
for path in session_abcs:
  if int(path.stem) in ref_nums:
    shutil.copyfile(path, 'abc_dataset/folk_rnn_abc_key_cleaned_title/' + path.name)

# %%
def convert_token(token):
  if isinstance(token, pyabc.Note):
    return f"{token.midi_pitch}//{token.duration}"
  if isinstance(token, pyabc.Rest):
    return f"{0}//{token.duration}"
  text = token._text
  if '"' in text:
    text = text.replace('"', '')
  if text == 'M':
    return None
  if text == '\n':
    return None
  if text in ['u', 'v', '.']:
    return None
  return text

def is_used_token(token):
  if isinstance(token, pyabc.ChordSymbol):
    return False
  return True

def _tune_to_list_of_str(tune):
  return [convert_token(token) for token in tune.tokens if is_used_token(token) and convert_token(token) is not None]

# %%
_tune_to_list_of_str(collect_tunes[0])
# Out:
# ['55//1.0',
#  '52//1.0',
#  '52//1.0',
#  '52//2.0',
#  '50//1.0',
#  '52//1.0',
#  '50//1.0',
#  '48//1.0',
#  '|',
#  '55//1.0',
#  '52//1.0',
#  '52//1.0',
#  '52//1.0',
#  '53//1.0',
#  '55//1.0',
#  '57//1.0',
#  '59//1.0',
#  '60//1.0',
#  '|',
#  '55//1.0',
#  '52//1.0',
#  '52//1.0',
#  '52//2.0',
#  '50//1.0',
#  '52//1.0',
#  '50//1.0',
#  '48//1.0',
#  '|',
#  '57//1.0',
#  '50//1.0',
#  '50//1.0',
#  '55//1.0',
#  '52//1.0',
#  '48//1.0',
#  '50//2.0',
#  '57//1.0',
#  '|',
#  '55//1.0',
#  '52//1.0',
#  '52//1.0',
#  '52//2.0',
#  '50//1.0',
#  '52//1.0',
#  '50//1.0',
#  '48//1.0',
#  '|',
#  '55//1.0',
#  '52//1.0',
#  '52//1.0',
#  '52//1.0',
#  '53//1.0',
#  '55//1.0',
#  '57//1.0',
#  '59//1.0',
#  '60//1.0',
#  '|',
#  '55//1.0',
#  '52//1.0',
#  '52//1.0',
#  '52//2.0',
#  '50//1.0',
#  '52//1.0',
#  '50//1.0',
#  '48//1.0',
#  '|',
#  '57//1.0',
#  '50//1.0',
#  '50//1.0',
#  '55//1.0',
#  '52//1.0',
#  '48//1.0',
#  '50//2.0',
#  '50//1.0',
#  '|',
# ...
