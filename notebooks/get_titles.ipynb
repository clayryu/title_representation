# %%
# %cd ..
# %load_ext autoreload
# %autoreload 2
# Out:
# /home/dasol/userdata/AI_music_generation_challenge

# %%
import pandas as pd
import torch
from torch.utils.data import Dataset, random_split
from transformers import GPT2Tokenizer, TrainingArguments, Trainer, GPT2LMHeadModel
from pathlib import Path
from pyabc import pyabc
from tqdm import tqdm

# %%
dir_path = "dataset/the_session/"
dir_path = Path(dir_path)
abc_list = list(dir_path.rglob('*.abc')) + list(dir_path.rglob('*.ABC'))

# %%
from urllib import request
import requests
from bs4 import BeautifulSoup
from collections import defaultdict
title_dict = defaultdict(list)

title_list = []
for page in tqdm(range(1, 1963)):
    url = 'https://thesession.org/tunes/search?type=&mode=&q=&page=' + f'{page}'
    request = requests.get(url)
    soup = BeautifulSoup(request.content, features='html.parser')
    request.close()

    find_title = soup.find('ol', attrs={'class':'manifest-inventory split'})
    for tune in find_title.findAll('li', attrs={'class':'manifest-item'}):
        title = tune.find('a', attrs={'class':'manifest-item-title'}).text
        title_dict['titles'].append(title)
# Out:
# 100%|██████████| 1962/1962 [1:22:17<00:00,  2.52s/it]

# %%
torch.save(title_dict, '/home/dasol/userdata/AI_music_generation_challenge/dasol_notebooks/session_title.pt')

# %%
session_pt = torch.load('/home/dasol/userdata/AI_music_generation_challenge/dasol_notebooks/session_title.pt')
session_titles = list(session_pt['titles'])
session_titles[:10]
# Out:
# ['Drowsy Maggie',
#  'The Kesh',
#  'Cooley’s',
#  'The Butterfly',
#  'Morrison’s',
#  'The Silver Spear',
#  'The Maid Behind The Bar',
#  'The Banshee',
#  'Banish Misfortune',
#  'Out On The Ocean']

# %%
tokenizer = GPT2Tokenizer.from_pretrained('gpt2-medium', bos_token='<|startoftext|>',
                                          eos_token='<|endoftext|>', pad_token='<|pad|>')
model = GPT2LMHeadModel.from_pretrained('gpt2-medium').cuda()
model.resize_token_embeddings(len(tokenizer))
# Out:
# Downloading:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/718 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Downloading:   0%|          | 0.00/1.52G [00:00<?, ?B/s]
# Embedding(50259, 1024)

# %%
session_titles
# Out:
# ['Drowsy Maggie',
#  'The Kesh',
#  'Cooley’s',
#  'The Butterfly',
#  'Morrison’s',
#  'The Silver Spear',
#  'The Maid Behind The Bar',
#  'The Banshee',
#  'Banish Misfortune',
#  'Out On The Ocean',
#  'The Wind That Shakes The Barley',
#  'Tam Lin',
#  'The Musical Priest',
#  'The Connaughtman’s Rambles',
#  'The Rights Of Man',
#  'The Blarney Pilgrim',
#  'King Of The Fairies',
#  'The Harvest Home',
#  'The Kid On The Mountain',
#  'The Gravel Walks',
#  'The Swallowtail',
#  'The Mason’s Apron',
#  'The Sally Gardens',
#  'The Lilting Banshee',
#  'Sí Beag Sí Mór',
#  'The Lark In The Morning',
#  'The Mountain Road',
#  'Saint Anne’s',
#  'The Boys Of Bluehill',
#  'The Cliffs Of Moher',
#  'Calliope House',
#  'The Star Of Munster',
#  'The Merry Blacksmith',
#  'The Cup Of Tea',
#  'The Congress',
#  'Off To California',
#  'Tripping Up The Stairs',
#  'The Morning Dew',
#  'Toss The Feathers',
#  'The Bucks Of Oranmore',
#  'Inisheer',
#  'The Irish Washerwoman',
#  'The Wise Maid',
#  'John Ryan’s',
#  'Miss McLeod’s',
#  'A Fig For A Kiss',
#  'The Pigeon On The Gate',
#  'The Road To Lisdoonvarna',
#  'My Darling Asleep',
#  'The Blackthorn Stick',
#  'The Earl’s Chair',
#  'The Britches Full Of Stitches',
#  'The Little Beggarman',
#  'The Mist Covered Mountain',
#  'The Monaghan',
#  'Julia Delaney’s',
#  'The Rocky Road To Dublin',
#  'Haste To The Wedding',
#  'Merrily Kissed The Quaker',
#  'The Humours Of Tulla',
#  'Jimmy Ward’s',
#  'Dusty Windowsills',
#  'Brenda Stubbert’s',
#  'The Foxhunters',
#  'Farewell To Ireland',
#  'The Kerry',
#  'The Foxhunter',
#  'Saddle The Pony',
#  'The Atholl Highlanders',
#  'The Otter’s Holt',
#  'Castle Kelly',
#  'The Ships Are Sailing',
#  'Rakish Paddy',
#  'The Dunmore Lasses',
#  'Garrett Barry’s',
#  'Tabhair Dom Do Lámh',
#  'The Man Of The House',
#  'I Buried My Wife And Danced On Her Grave',
#  'The Jig Of Slurs',
#  'MacLeod’s Farewell',
#  'The Sligo Maid',
#  'The Tarbolton',
#  'The Rose In The Heather',
#  'Ashokan Farewell',
#  'The Teetotaler’s',
#  'Rolling In The Ryegrass',
#  'Toss The Feathers',
#  'Donnybrook Fair',
#  'Sporting Paddy',
#  'The Geese In The Bog',
#  'The Rolling Waves',
#  'The Rambling Pitchfork',
#  'Over The Moor To Maggie',
#  'The Maid Of Mount Kisco',
#  'The Glass Of Beer',
#  'The Concertina',
#  'The Swallow’s Tail',
#  'The Ashplant',
#  'The Tenpenny Bit',
#  'The Salamanca',
#  'The Humours Of Glendart',
#  'Greig’s Pipes',
#  'Jenny’s Chickens',
#  'Music For A Found Harmonium',
#  'The South Wind',
#  'Fanny Power',
#  'The Fermoy Lasses',
#  'Frank’s',
#  'The Humours Of Ballyloughlin',
#  'Crested Hens',
#  'The Hag At The Churn',
#  'Farewell To Whalley Range',
#  'The Sailor’s Bonnet',
#  'The Kerfunten',
#  'The Flowers Of Edinburgh',
#  'Father Kelly’s',
#  'Planxty Irwin',
#  'Hector The Hero',
#  'Tobin’s Favourite',
#  'The Star Of The County Down',
#  'Whiskey Before Breakfast',
#  'Christmas Eve',
#  'The Rakes Of Kildare',
#  'The Ballydesmond',
#  'Catharsis',
#  'Spootiskerry',
#  'The Road To Errogie',
#  'The Drunken Landlady',
#  'The Old Favourite',
#  'The Old Copperplate',
#  'The High',
#  'The Tar Road To Sligo',
#  'The Frost Is All Over',
#  'The Roaring Barmaid',
#  'Sliabh Russell',
#  'MacArthur Road',
#  'Denis Murphy’s',
#  'O’Keeffe’s',
#  'Gallagher’s Frolics',
#  'The Old Bush',
#  'The Battering Ram',
#  'Willie Coleman’s',
#  'The Pipe On The Hob',
#  'Maggie In The Woods',
#  'An Phis Fhliuch',
#  'The Trip To Durrow',
#  'The Glen Of Aherlow',
#  'The Boys Of Malin',
#  'The Reconciliation',
#  'Chief O’Neill’s Favourite',
#  'Hardiman The Fiddler',
#  'The Drops Of Brandy',
#  'Carolan’s Concerto',
#  'Miss Monaghan',
#  'The Golden Keyboard',
#  'The Abbey',
#  'Josefin’s',
#  'The Trip To Pakistan',
#  'Old Hag, You Have Killed Me',
#  'Apples In Winter',
#  'The Cat’s Meow',
#  'The Foggy Dew',
#  'The Snowy Path',
#  'The Silver Spire',
#  'The Maids Of Mitchelstown',
#  'Brian Boru’s March',
#  'The Bird In The Bush',
#  'The Home Ruler',
#  'Dinkey’s',
#  'The Black Rogue',
#  'Swinging On The Gate',
#  'The Banks Of Lough Gowna',
#  'The Rakes Of Mallow',
#  'The Road To Lisdoonvarna',
#  'The Strayaway Child',
#  'The Morning Star',
#  'The Frieze Breeches',
#  'My Love Is In America',
#  'The Rolling Waves',
#  'The Virginia',
#  'The Woman Of The House',
#  'George White’s Favourite',
#  'The Killavil',
#  'Behind The Haystack',
#  'The Ships In Full Sail',
#  'The Leitrim Fancy',
#  'The Mug Of Brown Ale',
#  'The Coleraine',
#  'Scatter The Mud',
#  'Carolan’s Welcome',
#  'The Fairy Dance',
#  'Bill Sullivan’s',
#  'Soldier’s Joy',
#  'Jenny Nettle’s Fancy',
#  'Father O’Flynn',
#  'Lucy Campbell',
#  'The Cock And The Hen',
#  'Dick Gossip’s',
#  'The Lads Of Laois',
#  'Dr. Gilbert’s',
#  'The Castle',
#  'The Star Above The Garter',
#  'The Green Mountain',
#  'After The Battle Of Aughrim',
#  'The Killarney Boys Of Pleasure',
#  'Smash The Windows',
#  'The Flogging',
#  'Cronin’s',
#  'Bonaparte Crossing The Rhine',
#  'The White Petticoat',
#  'The Mouth Of The Tobique',
#  'The Bag Of Spuds',
#  'Maudabawn Chapel',
#  'The Trip To Sligo',
#  'The Moving Cloud',
#  'The Lochaber Badger',
#  'Beare Island',
#  'The Hag With The Money',
#  'The Galway Rambler',
#  'The Dark Island',
#  'Na Ceannabháin Bhána',
#  'The Cook In The Kitchen',
#  'The Humours Of Ennistymon',
#  'Last Night’s Fun',
#  'The Ballydesmond',
#  'The Hunter’s House',
#  'The Dawning Of The Day',
#  'Speed The Plough',
#  'The Devil’s Dream',
#  'The Bank Of Ireland',
#  'Langstrom’s Pony',
#  'The Mooncoin',
#  'The Green Fields Of Rossbeigh',
#  'Rolling In The Barrel',
#  'The Galway',
#  'The Roscommon',
#  'The Longford Collector',
#  'The Scholar',
#  'Mairi’s Wedding',
#  'The New Copperplate',
#  'Fisher’s',
#  'The Carraroe',
#  'Fred Finn’s',
#  'Tatter Jack Walsh',
#  'Sweeney’s Buttermilk',
#  'The Humours Of Tullycrine',
#  'Maggie’s Pancakes',
#  'O’Sullivan’s March',
#  'Denis Murphy’s',
#  'The Boyne Hunt',
#  'Master Crowley’s',
#  'The Dingle Regatta',
#  'The Green Groves Of Erin',
#  'The Humours Of Whiskey',
#  'Lord Mayo',
#  'The Clumsy Lover',
#  'The Belfast',
#  'Good Morning To Your Nightcap',
#  'Whelan’s',
#  'Lanigan’s Ball',
#  'Paddy Fahey’s',
#  'The Haunted House',
#  'Stan Chapman’s',
#  'Give Us A Drink Of Water',
#  'The Dublin',
#  'Far From Home',
#  'Music In The Glen',
#  'Jackie Coleman’s',
#  'Martin Wynne’s',
#  'The Boys Of The Lough',
#  'The Gold Ring',
#  'Kitty’s Wedding',
#  'Come West Along The Road',
#  'The Reel Of Rio',
#  'Tuttle’s',
#  'The Gander In The Pratie Hole',
#  'Farrel O’Gara’s',
#  'The Broken Pledge',
#  'Devanny’s Goat',
#  'The High Road To Linton',
#  'Lady Anne Montgomery',
#  'Paddy Ryan’s Dream',
#  'Elizabeth Kelly’s Delight',
#  'The Hunter’s Purse',
#  'Da New Rigged Ship',
#  'Drag Her Round The Road',
#  'Splendid Isolation',
#  'Da Slockit Light',
#  'Niel Gow’s Lament For His Second Wife',
#  'The Arran Boat Song',
#  'Jenny’s Welcome To Charlie',
#  'The Curlews',
#  'Paddy O’Rafferty',
#  'The Crooked Road To Dublin',
#  'Midnight On The Water',
#  'The Holly Bush',
#  'Pressed For Time',
#  'Jenny Dang The Weaver',
#  'The Plains Of Boyle',
#  'The Walls Of Liscarrol',
#  'Munster Buttermilk',
#  'The Red-Haired Lass',
#  'Porthole Of The Kelp',
#  'Down The Broom',
#  'The High Drive',
#  'Kitty Lie Over',
#  'I’ll Tell Me Ma',
#  'The Pride Of Petravore',
#  'The Primrose Lasses',
#  'Far Away',
#  'The Butlers Of Glen Avenue',
#  'Within A Mile Of Dublin',
#  'Margaret’s',
#  'Rip The Calico',
#  'Ramnee Ceilidh',
#  'The Trip To Athlone',
#  'Farewell To Chernobyl',
#  'The Blackberry Blossom',
#  'Pull The Knife And Stick It Again',
#  'The Providence',
#  'Her Long Dark Hair Flowing Down Her Back',
#  'The Monaghan Twig',
#  'The Creel Of Turf',
#  'Farewell To Erin',
#  'Sonny’s',
#  'Off She Goes',
#  'The Blackbird',
#  'Bonnie Kate',
#  'Christy Barry’s',
#  'Martin Wynne’s',
#  'The Skye Boat Song',
#  'Carolan’s Draught',
#  'The Miller’s Maggot',
#  'The Laurel Tree',
#  'The Tap Room',
#  'Reel Béatrice',
#  'The Jolly Tinker',
#  'Paddy Fahey’s',
#  'The Chicago',
#  'Spórt',
#  'The New Mown Meadows',
#  'Seán Sa Cheo',
#  'The Road To Glountane',
#  'The Eavesdropper',
#  'The Peeler’s Jacket',
#  'Tommy Peoples’',
#  'The Templehouse',
#  'Tell Her I Am',
#  'Jerry’s Beaver Hat',
#  'Dowd’s Favourite',
#  'The Boys Of Ballisodare',
#  'Ievan Polkka',
#  'Staten Island',
#  'King Of The Pipers',
#  'The Donegal Lass',
#  'The Orphan',
#  'The Torn Jacket',
#  'Eleanor Plunkett',
#  'The Drunken Sailor’s',
#  'The Flowers Of Red Hill',
#  'Superfly',
#  'Jump At The Sun',
#  'The Flowers Of Red Hill',
#  'Planxty Hewlett',
#  'Pachelbel’s Frolics',
#  'Lucy Farr’s',
#  'The Ballydesmond',
#  'Colonel Fraser',
#  'The Knotted Cord',
#  'The Spike Island Lasses',
#  'The Contradiction',
#  'Lad O’Beirne’s',
#  'Health To The Ladies',
#  'Drummond Castle',
#  'Tom Billy’s',
#  'The Rattlin’ Bog',
#  'The Belles Of Tipperary',
#  'The College Groves',
#  'The Cameronian',
#  'March Of The Kings Of Laois',
#  'Calum’s Road',
#  'The Old Maids Of Galway',
#  'The Guns Of The Magnificent Seven',
#  'The Lark In The Morning',
#  'The Traveller',
#  'Leaving Uist',
#  'Barrowburn',
#  'The Bag Of Potatoes',
#  'The Green Fields Of America',
#  'Dever The Dancer',
#  'Patsy Geary’s',
#  'Mayor Harrison’s Fedora',
#  'The Liverpool',
#  'The Rainy Day',
#  'Aaron’s Key',
#  'The Boys Of Ballisodare',
#  'The Donegal',
#  'The Legacy',
#  'Seanamhac Tube Station',
#  'Seamus Cooley’s',
#  'Dinny Delaney’s',
#  'Jack’s The Lad',
#  'The Skylark',
#  'Mouse In The Kitchen',
#  'The Galtee Rangers',
#  'The Trip To Herve’s',
#  'The Lonesome Boatman',
#  'The Shaskeen',
#  'Siobhan O’Donnell’s',
#  'The Wizard’s Walk',
#  'The Yellow Tinker',
#  'O’Rourke’s',
#  'The Derry Air',
#  'The Stack Of Barley',
#  'Willafjord',
#  'The Pipe On The Hob',
#  'The Cordal',
#  'Saint Patrick’s Day',
#  'Bunker Hill',
#  'Redican’s Mother',
#  'Bunker Hill',
#  'The Jug Of Punch',
#  'The Steampacket',
#  'Redican’s Mother',
#  'Mulqueeney’s',
#  'The Hare’s Paw',
#  'The Merry Sisters',
#  'The Peacock’s Feathers',
#  'Paddy Fahey’s',
#  'Comb Your Hair And Curl It',
#  'Palmer’s Gate',
#  'The Maid On The Green',
#  'The Lisnagun',
#  'The Sleeping Tune',
#  'The Floating Crowbar',
#  'Return From Fingal',
#  'The Sailor’s Wife',
#  'Sleepy Maggie',
#  'Eileen Curran',
#  'Big John McNeil',
#  'The Eel In The Sink',
#  'The Famous Ballymote',
#  'The Swaggering Jig',
#  'Dowd’s No. 9',
#  'The Last Pint',
#  'Da Full Rigged Ship',
#  'The Nine Points Of Roguery',
#  'Going To The Well For Water',
#  'She Moved Through The Fair',
#  'Sean Bui',
#  'The Heather Breeze',
#  'The Boys Of The Town',
#  'The Hag At The Spinning Wheel',
#  'The Devil In The Kitchen',
#  'Helvic Head',
#  'The Wandering Minstrel',
#  'Arthur Darley’s',
#  'Jenny’s Wedding',
#  'The Duke Of Leinster',
#  'The Golden Eagle',
#  'The Duke Of Leinster',
#  'Paddy’s Trip To Scotland',
#  'Scotch Mary',
#  'Cherish The Ladies',
#  'Molly Bán',
#  'This Is My Love, Do You Like Her?',
#  'Lord Inchiquin',
#  'The Brosna',
#  'The Green Fields Of Glentown',
#  'Terry ‘Cuz’ Teehan’s',
#  'Trim The Velvet',
#  'Terry ‘Cuz’ Teehan’s',
#  'The Lady On The Island',
#  'The Hut On Staffin Island',
#  'Caisleán An Óir',
#  'The Longford Tinker',
#  'Sheehan’s',
#  'The Ale Is Dear',
#  'Down By The Sally Gardens',
#  'Young Tom Ennis',
#  'Jean’s',
#  'Kiss The Maid Behind The Barrel',
#  'Boil The Breakfast Early',
#  'Amhrán Na Leabhar',
#  'The Cuil Aodha',
#  'Chanter’s Tune',
#  'The Laird Of Drumblair',
#  'Farewell To Connaught',
#  'The Nightingale',
#  'Spancil Hill',
#  'Cock O’ The North',
#  'Brian O’Lynn',
#  'Condon’s Frolics',
#  'Palm Sunday',
#  'The Old Blackthorn',
#  'Farewell To Whisky',
#  'The Hag’s Purse',
#  'The Gallowglass',
#  'The Three Sea Captains',
#  'The Sailor On The Rock',
#  'Sonny Brogan’s',
#  'Andy Renwick’s Ferret',
#  'The Pinch Of Snuff',
#  'Planxty George Brabazon',
#  'Cutting Bracken',
#  'Ar Éirinn Ní Neosfainn Cé Hí',
#  'Muireann’s',
#  'The Humours Of Ballyconnell',
#  'The Girl Who Broke My Heart',
#  'The Old Grey Goose',
#  'Sixpenny Money',
#  'The Hole In The Hedge',
#  'Contentment Is Wealth',
#  'The Ash Grove',
#  'Tommy’s Tarbukas',
#  'Alexander’s',
#  'Jacky Tar',
#  'The Crock Of Gold',
#  'The Tailor’s Twist',
#  'The Wild Irishman',
#  'Sleep Soond Ida Mornin’',
#  'Eddie Kelly’s',
#  'The Scotsman Over The Border',
#  'The Cape Breton Fiddlers’ Society’s Welcome To The Shetland Islands',
#  'The Lark On The Strand',
#  'The Fair Wind',
#  'Leslie’s March',
#  'Hand Me Down The Tackle',
#  'Fraher’s',
#  'The Maids Of Ardagh',
#  'The Maids Of Ardagh',
#  'Jenny Picking Cockles',
#  'The Wren',
#  'Strike The Gay Harp',
#  'Ger The Rigger',
#  'Kitty Goes A-Milking',
#  'McIntyre’s Fancy',
#  'The Pigtown Fling',
#  'Sean Reid’s',
#  'The Shetland Fiddler',
#  'Crowley’s',
#  'Farewell To Erin',
#  'Coen’s Memories',
#  'Shandon Bells',
#  'Autumn Child',
#  'Bill Harte’s',
#  'The Limerick Lasses',
#  'Moll Roe',
#  'Scotland The Brave',
#  'Behind The Bush In The Garden',
#  'The London Lasses',
#  'The Luachrachán’s',
#  'The Red Crow',
#  'The Bunch Of Keys',
#  'The Doon',
#  'Maud Millar',
#  'Hundred Pipers',
#  'Across The Black River',
#  'Rathlin Island',
#  'The Spotted Dog',
#  'The Dawn',
#  'Bang Your Frog On The Sofa',
#  'When Sick Is It Tea That You Want?',
#  'Ormond Sound',
#  'The Dogs Among The Bushes',
#  'The Munster Cloak',
#  'The Maids Of Castlebar',
#  'The Sheep In The Boat',
#  'The Malbay Shuffle',
#  'Love At The Endings',
#  'The Limestone Rock',
#  'Love At The Endings',
#  'Madame Bonaparte',
#  'The Maid At The Well',
#  'The Rollicking Boys Of Tandragee',
#  'The Harp And The Shamrock',
#  'Wrong Foot Forward',
#  'The Moon And The Seven Stars',
#  'Garryowen',
#  'Iníon Ní Scannláin',
#  'The Fisherman’s Island',
#  'The Ivy Leaf',
#  'The Mouse In The Mug',
#  'Donald Blue',
#  'Coleman’s Cross',
#  'Port Na bPúcaí',
#  'The Galway Girl',
#  'The Girl Of The House',
#  'Ookpik',
#  'Joe Derrane’s',
#  'The Man Of Aran',
#  'The Lilting Fisherman',
#  'The Princess Royal',
#  'The Graf Spee',
#  'Winnie Hayes’',
#  'The Cuckoo’s Nest',
#  'The Sweetness Of Mary',
#  'The Hills Of Glenorchy',
#  'Mo Ghile Mear',
#  'The Fox On The Town',
#  'Sergeant Early’s Dream',
#  'The Fox On The Town',
#  'Anderson’s',
#  'Around The World For Sport',
#  'An Seanduine Dóite',
#  'Spanish Lady',
#  'The Reel With The Birl',
#  'The Boy In The Gap',
#  'I Ne’er Shall Wean Her',
#  'The Trip To Windsor',
#  'Andy De Jarlis’',
#  'Hull’s',
#  'The Killavil Fancy',
#  'The Flax In Bloom',
#  'The Miller Of Droghan',
#  'Brendan Tonra’s',
#  'Mother’s Delight',
#  'Black Pat',
#  '250 To Vigo',
#  'The Tinker’s Daughter',
#  'The Lost And Found',
#  'The Bank Of Turf',
#  'The Tinker’s Daughter',
#  'The Blackbird',
#  'The Milliner’s Daughter',
#  'Flatwater Fran',
#  'The Bear Dance',
#  'The Humours Of Westport',
#  'Paddy Clancy’s',
#  'Will You Come Home With Me?',
#  'Islay Rant',
#  'Will You Come Home With Me?',
#  'Loch Leven Castle',
#  'Gypsy Princess',
#  'Are You Ready Yet?',
#  'The Dance Of The Honeybees',
#  'Shoe The Donkey',
#  'Charlie Hunter',
#  'Carrickfergus',
#  'The Dusty Miller',
#  'Bonaparte’s Retreat',
#  'Old Joe’s',
#  'Lord McDonald’s',
#  'The Boy In The Boat',
#  'Mná Na hÉireann',
#  'The Morpeth Rant',
#  'The Hare In The Corn',
#  'The Piper’s Despair',
#  'Frailach',
#  'Jim Donoghue’s',
#  'The Mountain Top',
#  'Farewell To Milltown',
#  'The Lovers’',
#  'Waterman’s',
#  'Captain O’Kane',
#  'The High Part Of The Road',
#  'The Yellow Wattle',
#  'The Humours Of Scarriff',
#  'Thunderhead',
#  'Ah Surely',
#  'The Derry',
#  'The Star Of The County Down',
#  'A Punch In The Dark',
#  'O’Neill’s March',
#  'The Sunny Banks',
#  'The Ladies Pantalettes',
#  'Pay The Reckoning',
#  'If We Hadn’t Any Women In The World',
#  'The Mist On The Mountain',
#  'The Cowboy',
#  'If We Hadn’t Any Women In The World',
#  'Jackson’s',
#  'Alice’s',
#  'The Maple Leaf',
#  'Up Against The Buachaláns',
#  'The North Star',
#  'The Oak Tree',
#  'If Ever You Were Mine',
#  'The Old Torn Petticoat',
#  'The Fairies’',
#  'The Fairies’',
#  'The Corner House',
#  'The Windmill',
#  'The Blackhaired Lass',
#  'The Wheels Of The World',
#  'Franc A’Phoill',
#  'Roaring Mary',
#  'The Scartaglen',
#  'The Killavil',
#  'The Crosses Of Annagh',
#  'The Crosses Of Annagh',
#  'Tommy Bhetty’s',
#  'Paddy Taylor’s',
#  'The Siege Of Ennis',
#  'King George IV',
#  'John Brennan’s',
#  'The Morning Thrush',
#  'Over The Waterfall',
#  'The Jewels Of The Ocean',
#  'Lord Gordon’s',
#  'The Handsome Young Maidens',
#  'Tongadale',
#  'The Frog In The Well',
#  'The Jig Runrig',
#  'My Cape Breton Home',
#  'Jessica’s',
#  'The Honeymoon',
#  'St. Kilda Wedding',
#  'The Stool Of Repentance',
#  'Ingonish',
#  'The Humours Of Kiltyclogher',
#  'The Stack Of Wheat',
#  'The Gooseberry Bush',
#  'Doctor O’Neill',
#  'Jackie Coleman’s',
#  'The Green Gates',
#  'Galway Bay',
#  'The Coalminer’s',
#  'The Chandelier',
#  'Scarce O’ Tatties',
#  'Kitty’s Rambles',
#  'Carolan’s Farewell To Music',
#  'McGoldrick’s',
#  'Jerusalem Ridge',
#  'Timmy Clifford’s',
#  'The Noon Lassies',
#  'The Diplodocus',
#  'Sonny Murray’s',
#  'Snug In The Blanket',
#  'The Irish',
#  'Snug In The Blanket',
#  'Bill Malley’s',
#  'Hair On The Gate',
#  'The Leaving Of Liverpool',
#  'The Flowing Bowl',
#  'Tom Ward’s Downfall',
#  'Peter Street',
#  'Tralee Gaol',
#  'Crabs In The Skillet',
#  'The Tempest',
#  'The Coolin',
#  'The Rakes Of Clonmel',
#  'Blind Mary',
#  'My Mind Will Never Be Easy',
#  'The Glen Road To Carrick',
#  'The Hungry Rock',
#  'The Wonder',
#  'Padraig O’Keefe’s',
#  'The Concert',
#  'The Queen Of The Rushes',
#  'The Concert',
#  'The Long Drop',
#  'Another Jig Will Do',
#  'The Spey In Spate',
#  'Peacock Follow The Hen',
#  'Kevin McHugh’s',
#  'The Raggle Taggle Gypsies',
#  'The Ballydesmond',
#  'The Cat Rambles To The Child’s Saucepan',
#  'The Forty-Two Pound Cheque',
#  'Bantry Bay',
#  'The Forty-Two Pound Cheque',
#  'Dan Collins’ Father’s',
#  'Mac’s Fancy',
#  'Anything For John Joe',
#  'The Whistling Postman',
#  'Soggy’s',
#  'Bó Mhín Na Toitean',
#  'Old Grey Cat',
#  'The Kitchen Girl',
#  'Sporting Nell',
#  'The Kitchen Girl',
#  'Táimse Im’ Chodladh',
#  'The Mullingar Races',
#  'Fleur De Mandragore',
#  'Stone Of Destiny',
#  'Old John’s',
#  'Teampall An Ghleanntáin',
#  'Dick Sherlock’s',
#  'The Easy Club',
#  'John Stenson’s',
#  'Old Man Dillon',
#  'Coleman’s',
#  'Turkey In The Straw',
#  'The Trip To Birmingham',
#  'Crossing The Minch',
#  'The Beeswing',
#  'The Edinburgh Rock',
#  'The Mill House',
#  'The Grumbling Old Man And Woman',
#  'The Dear Irish Boy',
#  'The Marino',
#  'The Grumbling Old Man And Woman',
#  'The Kylebrack Rambler',
#  'March Of The Meeatoiteen Bull',
#  'Tommy Peoples’',
#  'The Five Mile Chase',
#  'Roddy McDonald’s Fancy',
#  'The Bunch Of Green Rushes',
#  'Paddy Fahey’s',
#  'Bog An Lochan',
#  'Have A Drink With Me',
#  'The Rambler',
#  'Larry O’Gaff’s',
#  'Captain Campbell',
#  'The Highlander’s Farewell To Ireland',
#  'Touch Me If You Dare',
#  'John Doherty’s',
#  'Martin Wynne’s',
#  'Heaton Chapel',
#  'Heaton Chapel',
#  'Mulhaire’s',
#  'The Cameron Highlanders',
#  'The Sporting Pitchfork',
#  'Shove The Pig’s Foot A Little Closer To The Fire',
#  'Sailing Into Walpole’s Marsh',
#  'The Baltimore Salute',
#  'The Drunken Tinker',
#  'The Beauty Spot',
#  'The Mossy Banks',
#  'The Countess Cathleen',
#  'The Rookery',
#  'Paddy On The Turnpike',
#  'The Air Tune',
#  'Barney Brannigan',
#  'The Gatehouse Maid',
#  'A Trip To The Cottage',
#  'The Cow That Ate The Blanket',
#  'Scarborough Fair',
#  'Nóra Críona',
#  'Forget Me Not',
#  'Wing Commander Donald Mackenzie’s',
#  'The Rose Tree',
#  'The Four Courts',
#  'Waiting For The Federals',
#  'The Tolka',
#  'Green Grow The Rushes',
#  'Queen Of The Fair',
#  'The Eagle’s Whistle',
#  'The Exile Of Erin',
#  'The Eagle’s Whistle',
#  'Roslyn Castle',
#  'The Sunset',
#  'The Dairy Maid',
#  'The Knights Of Saint Patrick',
#  'Coffey’s',
#  'Fasten The Leg In Her',
#  'Bulgarian Red',
#  'When The Cock Crows It Is Day',
#  'Sporting Molly',
#  'Sheepskins And Beeswax',
#  'The Maid In The Meadow',
#  'The Sandymount',
#  'Archibald McDonald Of Keppoch',
#  'The Green Fields Of Woodford',
#  'The Gravel Walks',
#  'Corney Is Coming',
#  'The Lakes Of Ponchartrain',
#  'The Iron Man',
#  'The Flowing Tide',
#  'The Factory Smoke',
#  'Throw The Beetle At Her',
#  'The Galway Belle',
#  'Miss Thornton’s',
#  'The Cuil Aodha',
#  'Bonaparte Crossing The Alps',
#  'Lough Mountain',
#  'Devils Of Dublin',
#  'The Holy Land',
#  'Richard Dwyer’s',
#  'Lough Mountain',
#  'Tie The Bonnet',
#  'The Convenience',
#  'Amazing Grace',
#  'The Enchanted Lady',
#  'Jimmy’s Return',
#  'L’Air Mignonne',
#  'Up In The Air',
#  'The Flooded Road To Glenties',
#  'President Garfield’s',
#  'The Flooded Road To Glenties',
#  'The Boys Of The Town',
#  'The Humours Of Drinagh',
#  'Allistrum’s March',
#  'The Keel Row',
#  'The Minstrel Boy',
#  'The Flower Of The Flock',
#  'Dunphy’s',
#  'The Goodnatured Man',
#  'Maggie Brown’s Favourite',
#  'The Coming Of Spring',
#  'Maggie Brown’s Favourite',
#  'The Foggy Dew',
#  'The Luck Penny',
#  'The Parting Glass',
#  'Finnegan’s Wake',
#  'The Reel Of Mullinavat',
#  'The Scartaglen',
#  'The Bus Stop',
#  'The Little Diamond',
#  'Loch Lomond',
#  'Murphy’s',
#  'Popcorn Behaviour',
#  'Master McDermott’s',
#  'Sweeney’s',
#  'Tommy Coen’s',
#  'The Whistler At The Wake',
#  'Salmon Tails Up The Water',
#  'The Toormore',
#  'The Belharbour',
#  'Walsh’s',
#  'Happy To Meet, Sorry To Part',
#  'The Coachman’s Whip',
#  'The Belharbour',
#  'Greensleeves',
#  'The Job Of Journeywork',
#  'The Woodcock',
#  'Roddy McCorley',
#  'The Mother And Child',
#  'Michael Russell’s',
#  'Michael Russell’s',
#  'Roddy McCorley',
#  'Speed The Plough',
#  'Tom Busby’s',
#  'The Noisy Curlew',
#  'The Arkansas Traveler',
#  'The Repeal Of The Union',
#  'Trip To Skye',
#  'The Burning Of The Piper’s Hut',
#  'The One That Was Lost',
#  'The Clare',
#  'Will You Come Down To Limerick',
#  'John Kelly’s',
#  'The Burning Of The Piper’s Hut',
#  'The One That Was Lost',
#  'The Twelve Pins',
#  'Sheila Coyle’s',
#  'Kilnamona',
#  'The House Of Hamill',
#  'The Old Flail',
#  'The House Of Hamill',
#  'The Big Reel Of Ballynacally',
#  'The Wild Rover',
#  'Goodbye Miss Goodavich',
#  'Jock Brown’s 70th',
#  'The Pinch Of Snuff',
#  'The Mortgage Burn',
#  'The Bird’s Nest',
#  'The Ace And Deuce Of Pipering',
#  'Cooley’s',
#  'Garrett Barry’s',
#  'The Dusty Miller',
#  'The Humours Of Lisheen',
#  'Emmett’s Hedgehog',
#  'St. Patrick’s An Dro',
#  'Rodney’s Glory',
#  'Matt Peoples’',
#  'Kalyana',
#  'Ornette’s Trip To Belfast',
#  'The Irish Rover',
#  'Connie The Soldier',
#  'Patsy Touhey’s',
#  'The Culfadda',
#  'Johnny Cope',
#  'John Brosnan’s',
#  'Castlerock Road',
#  'The Parting Glass',
#  'The Pretty Girl Milking Her Cow',
#  'The Kilfenora',
#  'The Exile’s Jig',
#  'The Bride’s Favourite',
#  'The Singing Stream',
#  'The Little Cascade',
#  'The Famous Baravan',
#  'The First House In Connaught',
#  'Cucanandy',
#  'The Cuil Aodha',
#  'The Boys Of Portaferry',
#  'Cleveland Park',
#  'The Cliffs Of Moher',
#  'Flatbush',
#  'The Road To Cashel',
#  'The Fairy Queen',
#  'Flagstone Of Memories',
#  'Haley’s',
#  'The Boys Of Ballivanich',
#  'The Kilmovee',
#  'The Muckin’ O’ Geordie’s Byre',
#  'The Blacksmith',
#  'The Curragh Races',
#  'The Mist-Covered Mountains Of Home',
#  'The Milky Way',
#  'Loftus Jones',
#  'Pretty Peg',
#  'Campbell’s Farewell To Red Gap',
#  'The History Man',
#  'The Ballintore Fancy',
#  'The High Level',
#  'Molly MacAlpin',
#  'The Kilfenora',
#  ...]

# %%
class TTLDataset(Dataset):
    def __init__(self, txt_list, tokenizer, max_length):
        self.input_ids = []
        self.attn_masks = []
        self.labels = []
        for txt in txt_list:
            encodings_dict = tokenizer('<|startoftext|>' + txt + '<|endoftext|>', truncation=True,
                                       max_length=max_length, padding="max_length")
            self.input_ids.append(torch.tensor(encodings_dict['input_ids']))
            self.attn_masks.append(torch.tensor(encodings_dict['attention_mask']))

    def __len__(self):
        return len(self.input_ids)

    def __getitem__(self, idx):
        return self.input_ids[idx], self.attn_masks[idx]

# %%
max_length = max([len(tokenizer.encode(title)) for title in session_titles])
dataset = TTLDataset(session_titles, tokenizer, max_length=max_length)
train_size = int(0.9 * len(dataset))
train_dataset, val_dataset = random_split(dataset, [train_size, len(dataset) - train_size])

# %%
len(train_dataset), max_length
# Out:
# (17658, 29)

# %%
tokenizer.decode(train_dataset[3][0])
# Out:
# '<|startoftext|> Grant’s Rant<|endoftext|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|>'

# %%
training_args = TrainingArguments(output_dir='./results', num_train_epochs=5, logging_steps=100, save_steps=5000,
                                  per_device_train_batch_size=10, per_device_eval_batch_size=1,
                                  warmup_steps=10, weight_decay=0.05, logging_dir='./logs', report_to = 'none')

# %%
Trainer(model=model,  args=training_args, train_dataset=train_dataset, 
        eval_dataset=val_dataset, data_collator=lambda data: {'input_ids': torch.stack([f[0] for f in data]),
                                                              'attention_mask': torch.stack([f[1] for f in data]),
                                                              'labels': torch.stack([f[0] for f in data])}).train()
# Out:
# /home/dasol/.local/lib/python3.8/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 17658
#   Num Epochs = 5
#   Instantaneous batch size per device = 10
#   Total train batch size (w. parallel, distributed & accumulation) = 10
#   Gradient Accumulation steps = 1
#   Total optimization steps = 8830
#     <div>
#
#       <progress value='8830' max='8830' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [8830/8830 16:46, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>2.119000</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.945100</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.894100</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.873400</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.870400</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.865000</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.871100</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.876000</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.857000</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.841500</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.810900</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.829400</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>0.835500</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.816800</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.801900</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.825100</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>0.809500</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.760200</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>0.669700</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.686500</td>
#     </tr>
#     <tr>
#       <td>2100</td>
#       <td>0.662600</td>
#     </tr>
#     <tr>
#       <td>2200</td>
#       <td>0.656400</td>
#     </tr>
#     <tr>
#       <td>2300</td>
#       <td>0.677800</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>0.655100</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.670000</td>
#     </tr>
#     <tr>
#       <td>2600</td>
#       <td>0.668400</td>
#     </tr>
#     <tr>
#       <td>2700</td>
#       <td>0.662400</td>
#     </tr>
#     <tr>
#       <td>2800</td>
#       <td>0.676800</td>
#     </tr>
#     <tr>
#       <td>2900</td>
#       <td>0.686000</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.655300</td>
#     </tr>
#     <tr>
#       <td>3100</td>
#       <td>0.656900</td>
#     </tr>
#     <tr>
#       <td>3200</td>
#       <td>0.692400</td>
#     </tr>
#     <tr>
#       <td>3300</td>
#       <td>0.669400</td>
#     </tr>
#     <tr>
#       <td>3400</td>
#       <td>0.657200</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.666300</td>
#     </tr>
#     <tr>
#       <td>3600</td>
#       <td>0.574300</td>
#     </tr>
#     <tr>
#       <td>3700</td>
#       <td>0.554200</td>
#     </tr>
#     <tr>
#       <td>3800</td>
#       <td>0.559700</td>
#     </tr>
#     <tr>
#       <td>3900</td>
#       <td>0.566100</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.552800</td>
#     </tr>
#     <tr>
#       <td>4100</td>
#       <td>0.555000</td>
#     </tr>
#     <tr>
#       <td>4200</td>
#       <td>0.568700</td>
#     </tr>
#     <tr>
#       <td>4300</td>
#       <td>0.561700</td>
#     </tr>
#     <tr>
#       <td>4400</td>
#       <td>0.562900</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.560200</td>
#     </tr>
#     <tr>
#       <td>4600</td>
#       <td>0.551800</td>
#     </tr>
#     <tr>
#       <td>4700</td>
#       <td>0.560300</td>
#     </tr>
#     <tr>
#       <td>4800</td>
#       <td>0.569400</td>
#     </tr>
#     <tr>
#       <td>4900</td>
#       <td>0.576800</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.555200</td>
#     </tr>
#     <tr>
#       <td>5100</td>
#       <td>0.572400</td>
#     </tr>
#     <tr>
#       <td>5200</td>
#       <td>0.570400</td>
#     </tr>
#     <tr>
#       <td>5300</td>
#       <td>0.546600</td>
#     </tr>
#     <tr>
#       <td>5400</td>
#       <td>0.474500</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.487000</td>
#     </tr>
#     <tr>
#       <td>5600</td>
#       <td>0.483300</td>
#     </tr>
#     <tr>
#       <td>5700</td>
#       <td>0.484700</td>
#     </tr>
#     <tr>
#       <td>5800</td>
#       <td>0.488000</td>
#     </tr>
#     <tr>
#       <td>5900</td>
#       <td>0.495700</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.494300</td>
#     </tr>
#     <tr>
#       <td>6100</td>
#       <td>0.497200</td>
#     </tr>
#     <tr>
#       <td>6200</td>
#       <td>0.488600</td>
#     </tr>
#     <tr>
#       <td>6300</td>
#       <td>0.495200</td>
#     </tr>
#     <tr>
#       <td>6400</td>
#       <td>0.493900</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>0.497500</td>
#     </tr>
#     <tr>
#       <td>6600</td>
#       <td>0.499000</td>
#     </tr>
#     <tr>
#       <td>6700</td>
#       <td>0.490100</td>
#     </tr>
#     <tr>
#       <td>6800</td>
#       <td>0.486200</td>
#     </tr>
#     <tr>
#       <td>6900</td>
#       <td>0.490200</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.489700</td>
#     </tr>
#     <tr>
#       <td>7100</td>
#       <td>0.470100</td>
#     </tr>
#     <tr>
#       <td>7200</td>
#       <td>0.434900</td>
#     </tr>
#     <tr>
#       <td>7300</td>
#       <td>0.434700</td>
#     </tr>
#     <tr>
#       <td>7400</td>
#       <td>0.455300</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>0.444200</td>
#     </tr>
#     <tr>
#       <td>7600</td>
#       <td>0.446300</td>
#     </tr>
#     <tr>
#       <td>7700</td>
#       <td>0.448000</td>
#     </tr>
#     <tr>
#       <td>7800</td>
#       <td>0.444300</td>
#     </tr>
#     <tr>
#       <td>7900</td>
#       <td>0.451100</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.445400</td>
#     </tr>
#     <tr>
#       <td>8100</td>
#       <td>0.449500</td>
#     </tr>
#     <tr>
#       <td>8200</td>
#       <td>0.447800</td>
#     </tr>
#     <tr>
#       <td>8300</td>
#       <td>0.444500</td>
#     </tr>
#     <tr>
#       <td>8400</td>
#       <td>0.444500</td>
#     </tr>
#     <tr>
#       <td>8500</td>
#       <td>0.454000</td>
#     </tr>
#     <tr>
#       <td>8600</td>
#       <td>0.443300</td>
#     </tr>
#     <tr>
#       <td>8700</td>
#       <td>0.445300</td>
#     </tr>
#     <tr>
#       <td>8800</td>
#       <td>0.450400</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to ./results/checkpoint-5000
# Configuration saved in ./results/checkpoint-5000/config.json
# Model weights saved in ./results/checkpoint-5000/pytorch_model.bin
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=8830, training_loss=0.6173514020537466, metrics={'train_runtime': 1007.1254, 'train_samples_per_second': 87.665, 'train_steps_per_second': 8.768, 'total_flos': 4644247158743040.0, 'train_loss': 0.6173514020537466, 'epoch': 5.0})

# %%
generated = tokenizer("<|startoftext|> ", return_tensors="pt").input_ids.cuda()

sample_outputs = model.generate(generated, do_sample=True, top_k=50, 
                                max_length=30, top_p=0.95, temperature=1.9, num_return_sequences=100)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
for i, sample_output in enumerate(sample_outputs):
    print("{}: {}".format(i, tokenizer.decode(sample_output, skip_special_tokens=True)))
# Out:
# 0:  igeonian
# 1:  ’Widowinden
# 2:  ’Crow Row Doth Arrive
# 3: ????? O �er Bread
# 4:  ier M. Holland
# 5:  ____________
# 6:  icky Irish
# 7:    W Geordie Y Fuwch
# 8:  ______________ Side 1 ______________ Side 2
# 9:  iddow
# 10:  ́Wearmouth Cottage
# 11:  eryanshet  Dhomhone
# 12:  xtreme étaitienne
# 13:  Âñeedà Sgé Rámsés
# 14:  _____________________________________________________
# 15:  ____ Munch
# 16:  ’Uvin Bair
# 17:  ich Bin Jeh Sion Isengard Isogen
# 18:  eryn Terracotta Hilltop
# 19:  ét Fête Aux Briandntistriens
# 20:   Sliabh Dave
# 21:   Hungarian Cottage
# 22:  ’n Coleman A
# 23:   Errigal Eadhte Gledherty
# 24:  Â Stenson’s
# 25:   Søren Kier
# 26:  ’Toir I bEdgar
# 27:    Mrs Flanagan Of Tulse Ten Minutes ’ Seven
# 28: ???? A Tribute From David
# 29:  _____, But I Can’t Dance
# 30: ?????
# 31:  ́ireann Smithe An Culyek An Øllagon
# 32:  ********, A Child’s Welcome From America
# 33:  ________ The Farmer Boy
# 34:  était Drummond
# 35:  ________________
# 36:   Dn y Wuallwynyn O Briyn
# 37:    The Reelin Horn
# 38:  _____ North
# 39:  ige A Chvech B
# 40:  ikki
# 41: ????O The Hedge Go Tender
# 42:  ̄r Aberfoyle ́r Stewart
# 43:  ipsic ’hyndobangs
# 44:  étern, Emmentofflais And Marcelaich
# 45:  Âneille’s
# 46:  ́�r Éireann Ar Fhic Uist
# 47:  _____
# 48:  izak Reel 2 Reel 9 El Coiz
# 49:   My Bonny Stubbies
# 50:  不, Leitrim Flautist
# 51:  ෋෻�d Fa Ni Mhico Ri Myuilik
# 52:  ________________________?
# 53:   Fuchsia
# 54: ????? Is This Canada?
# 55:  ________________ DSO
# 56:  ich izeith Mi Cristo
# 57:  _____
# 58:   Gabe’s Delight
# 59:  ikoban Mune Takka Takk
# 60:    Dorn’s Sheep
# 61:  ipsum Rulings
# 62: ????????
# 63:  Ân Laínn Har Coinagh
# 64:  ́’ Deixi Moll’s
# 65:  ________________________________________________________________ (No-oile Plaudy Celynn Ceilios Peegynon
# 66: ????? Today At Eight Tomorrow Three
# 67:   -Editing
# 68:  ixit Bodhi ipsum Jeh Dao Kew
# 69:  ____ South Bend
# 70:  _____
# 71:  �thins Keshi Mhic Chailin Laoi
# 72:  igiobull Highlandman
# 73:
# 74:  _______________________ Wellesley Chisholm Cofre President
# 75:  igonvinvented
# 76:  ෙh Dhúanh ୦ Dholla’n At Sailevelach
# 77:
# 78:  igonuar
# 79:   My Heather Hills
# 80:   Córdoba
# 81:   Charlie McKerron’s Welcome Return
# 82:  ́thle Da Da H́ole Da Luh
# 83:  igiuremaizak
# 84:  _____________
# 85:  izakorrectionary
# 86:  ’Erre-Île
# 87:  ____ Nightcap
# 88:   Dornoch Dùmhair
# 89:  irlidée Helen De Brunais
# 90:  �� Rockland
# 91:  était à Martin
# 92:  iz Kuiper
# 93:  ���  ’ùxty
# 94:  � Ní Shakin Glou
# 95:    Spidec- t Hackberry
# 96:  ixot Salvia
# 97:  erthee Balkan
# 98:  ไn  faol ’ Awais
# 99:  ́heàna ́n Mo My Lírin A’ Mo Me My Líg

# %%
prompt_text = ' '

encoded_prompt = tokenizer.encode(prompt_text, add_special_tokens=False, return_tensors="pt").cuda()
output_sequences = model.generate(
    input_ids=encoded_prompt,
    max_length=max_length,
    temperature=0.7,
    top_k=0,
    top_p=0.9,
    repetition_penalty=1.0,
    do_sample=True,
    num_return_sequences=100,
)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
for i, output in enumerate(output_sequences):
    print("{}: {}".format(i, tokenizer.decode(output, skip_special_tokens=True)))
# Out:
# 0:  The Blue Shutters
# 1:  Gan Ainm
# 2:  The Purple Wisent
# 3:  The Blue Ball
# 4:  The Kilkenny Girl
# 5:  Reel For Angus
# 6:  The Trip To Kilmurry
# 7:  Reel Des Ti-Minous
# 8:  The Hen’s March To Winter
# 9:  Molly From Monro
# 10:  The Fairy’s Dream
# 11:  The Ballymun Regatta
# 12:  Saratoga
# 13:  Trip To Kilkenny
# 14:  The Post Road To Boston
# 15:  The Doon-Hampstead
# 16:  Sylvain Barou’s
# 17:  The Hags Money
# 18:  The Wishing Tree
# 19:  The Road To Sligo
# 20:  O’Connor’s
# 21:  Maggie’s
# 22:  The Old Grey Goose
# 23:  The New Brig Of Glasgow
# 24:  The Piper’s Picnic
# 25:  Byrne’s
# 26:  The Crooked Stovepipe
# 27:  The Barnacle
# 28:  The Galway Farmer
# 29:  The Rat In The Kitchen
# 30:  Bwlch Llanberis
# 31:  The Monoceros
# 32:  Hommage A Guy Thomas
# 33:  The Old Woman From The Glen
# 34:  The Rambuck’s
# 35:  The Lads Of Alnwick
# 36:  The Fox In The Henhouse
# 37:  The Maids Of Ardagh
# 38:  The Mighty Turtledove
# 39:  The Whirlpool
# 40:  The Streamstown
# 41:  A Tune For You, Dear One
# 42:  The New York
# 43:  The Merry Maids Of Fife
# 44:  The Men Of The Deeps
# 45:  The Little Red Lark
# 46:  The Lads Of Foss
# 47:  The Handsome Brothers
# 48:  The Merry Maids Of Brittany
# 49:  The Humours Of Bath
# 50:  The Old Man’s Blackthorn Stick
# 51:  Paddy Fahey’s
# 52:  The Old Man’s Blackthorn Stick
# 53:  The Trip To Ballyshannon
# 54:  The Lads Of Morna
# 55:  Paddy Fahey’s
# 56:  The Sligo
# 57:  The Old Man’s Blackthorn Stick
# 58:  The Honeysuckle
# 59:  Laughing Molly
# 60:  The Copperplate
# 61:  Eddie Duffy’s Favourite
# 62:  The Weaver’s Delight
# 63:  The Ornery
# 64:  The Mad Hatter
# 65:  The Morning Dance
# 66:  The Afterparty
# 67:  The Boys Of The Town
# 68:  Dot’s
# 69:  The Ballydesmond
# 70:  The Crooked Wood
# 71:  The Old Wheel Of Fortune
# 72:  The Three Sisters
# 73:  Lament For The Kerry Fisherman
# 74:  The Golden Wreath
# 75:  Kitty’s
# 76:  The Whistling Postman
# 77:  The End Of Winter
# 78:  The New House
# 79:  The Mummer’s
# 80:  The Galway Rambler
# 81:  The Jolly Ploughboy
# 82:  Beeswing
# 83:  Carmarthen
# 84:  The Stolen Kiss
# 85:  The Shepherd’s Daughter
# 86:  The Winding Road
# 87:  The Piper’s Whim
# 88:  The Lisdoonvarna
# 89:  John Donne’s
# 90:  Farewell To The Isle Of Skye
# 91:  The North Star
# 92:  The Sinking Pint
# 93:  The Ballydesmond
# 94:  Patsy Campbell
# 95:  The Weave Road
# 96:  The Lowthers
# 97:  The Stolen Bicycle
# 98:  The Trip To Fanore
# 99:  The Curragh
